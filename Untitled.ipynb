# %%
from __future__ import absolute_import, division, print_function
#word encoding
import codecs
#regex search files really fast
import glob
#concurrency running multiple threads
import multiprocessing
import os
import pprint
import re
import nltk
import gensim.models.word2vec as w2v
#dimentionality reduction VIDEO-Visualise dataset easily
import sklearn.manifold
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
#process
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to /home/neptune/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/neptune/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
from_filenames = sorted(glob.glob("*.from"))
to_filenames = sorted(glob.glob("*.to"))
from_filenames[1]
# Out:
# 'train.from'

# %%
corpus_raw = u""
for book_filename in from_filenames:
    print("Reading '{0}'...".format(book_filename))
    with codecs.open(book_filename, "r", "utf-8") as book_file:
        corpus_raw += book_file.read()
    print("Corpus is now {0} characters long".format(len(corpus_raw)))
    print()
    
for book_filename in to_filenames:
    print("Reading '{0}'...".format(book_filename))
    with codecs.open(book_filename, "r", "utf-8") as book_file:
        corpus_raw += book_file.read()
    print("Corpus is now {0} characters long".format(len(corpus_raw)))
    print()
# Out:
# Reading 'test.from'...
# Corpus is now 458651 characters long
#
# Reading 'train.from'...
# Corpus is now 31156911 characters long
#
# Reading 'test.to'...
# Corpus is now 31576921 characters long
#
# Reading 'train.to'...
# Corpus is now 59727262 characters long

# %%
tokenizer = nltk.data.load('tokenizers/punkt/english.pickle')

# %%
raw_sentences = tokenizer.tokenize(corpus_raw)

# %%
def sentence_to_wordlist(raw):
    clean = re.sub("[^a-zA-Z]"," ", raw)
    words = clean.split()
    return words

# %%
sentences = []
for raw_sentence in raw_sentences:
    if len(raw_sentence) > 0:
        sentences.append(sentence_to_wordlist(raw_sentence))

# %%
print(raw_sentences[5])
print(sentence_to_wordlist(raw_sentences[5]))
token_count = sum([len(sentence) for sentence in sentences])
print("The book corpus contains {0:,} tokens".format(token_count))
# Out:
# newlinechar
# WHO IS GILBERT?
# ['newlinechar', 'WHO', 'IS', 'GILBERT']
# The book corpus contains 10,803,198 tokens

# %%
#ONCE we have vectors
#step 3 - build model
#3 main tasks that vectors help with
#DISTANCE, SIMILARITY, RANKING

# Dimensionality of the resulting word vectors.
#more dimensions, more computationally expensive to train
#but also more accurate
#more dimensions = more generalized
num_features = 300
# Minimum word count threshold.
min_word_count = 3

# Number of threads to run in parallel.
#more workers, faster we train
num_workers = multiprocessing.cpu_count()

# Context window length.
context_size = 7

# Downsample setting for frequent words.
#0 - 1e-5 is good for this
downsampling = 1e-3

# Seed for the RNG, to make the results reproducible.
#random number generator
#deterministic, good for debugging
seed = 1

# %%
thrones2vec = w2v.Word2Vec(
    sg=1,
    seed=seed,
    workers=num_workers,
    size=num_features,
    min_count=min_word_count,
    window=context_size,
    sample=downsampling
)

# %%
thrones2vec.build_vocab(sentences)

# %%
print("Word2Vec vocabulary length:", len(thrones2vec.wv.vocab))
# Out:
# Word2Vec vocabulary length: 77884

# %%
thrones2vec.train(sentences,total_examples=thrones2vec.corpus_count,epochs=10)
# Out:
# (83798656, 108031980)

# %%
if not os.path.exists("trained"):
    os.makedirs("trained")
    
thrones2vec.save(os.path.join("trained", "model.w2v"))

# %%
thrones2vec = w2v.Word2Vec.load(os.path.join("trained", "model.w2v"))

# %%
tsne = sklearn.manifold.TSNE(n_components=2, random_state=0)

# %%
all_word_vectors_matrix = thrones2vec.wv.syn0
# Out:
# /home/neptune/.local/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `syn0` (Attribute will be removed in 4.0.0, use self.wv.vectors instead).
#   """Entry point for launching an IPython kernel.

# %%
all_word_vectors_matrix_2d = tsne.fit_transform(all_word_vectors_matrix)

# %%
points = pd.DataFrame(
    [
        (word, coords[0], coords[1])
        for word, coords in [
            (word, all_word_vectors_matrix_2d[thrones2vec.wv.vocab[word].index])
            for word in thrones2vec.wv.vocab
        ]
    ],
    columns=["word", "x", "y"]
)

# %%
points.head(10)
# Out:
#          word          x          y
# 0  Forgetting -17.578451   1.688756
# 1        song -19.603848  -1.347618
# 2      lyrics -16.130171  -0.194588
# 3          If   2.252301 -11.594135
# 4         you   3.697955 -11.103528
# 5          re  -4.610470  -9.376789
# 6       going   2.132934 -12.827708
# 7          to   6.756152  -8.915031
# 8        sing  -4.338074 -22.729729
# 9         the   1.962314   0.959264

# %%
sns.set_context("poster")

# %%
points.plot.scatter("x", "y", s=10, figsize=(20, 12))

# %%
def plot_region(x_bounds, y_bounds):
    slice = points[
        (x_bounds[0] <= points.x) &
        (points.x <= x_bounds[1]) & 
        (y_bounds[0] <= points.y) &
        (points.y <= y_bounds[1])
    ]
    
    ax = slice.plot.scatter("x", "y", s=35, figsize=(10, 8))
    for i, point in slice.iterrows():
        ax.text(point.x + 0.005, point.y + 0.005, point.word, fontsize=11)

# %%
plot_region(x_bounds=(4.0, 4.2), y_bounds=(-0.5, -0.1))

# %%
plot_region(x_bounds=(0, 1), y_bounds=(4, 4.5))
